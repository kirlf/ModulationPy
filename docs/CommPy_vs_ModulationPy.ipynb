# %%
#!pip install scikit-commpy
#!pip install ModulationPy

# %%
import numpy as np
import commpy.modulation as commpy_modulation
from ModulationPy import PSKModem

# %%
msg = np.random.randint(0, 2, int(1e4))

# %% [markdown]
# ## ModulationPy

# %%
modem = PSKModem(4) # our class initialization
m = modem.modulate(msg)

# %%
# %%timeit
m = modem.modulate(msg)
# Out:
# 13.9 ms ± 1.78 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
modem.demodulate(m) # demodulation # demodulation
# Out:
# 506 µs ± 38.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ## CommPy

# %%
modem = commpy_modulation.PSKModem(4)
m = modem.modulate(msg)

# %%
# %%timeit
m = modem.modulate(msg)
# Out:
# 14.2 ms ± 869 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
modem.demodulate(m, demod_type='soft')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/commpy/modulation.py:97: RuntimeWarning: divide by zero encountered in double_scalars
#   (-abs(current_symbol - self.constellation[const_index]) ** 2) / noise_var)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/commpy/modulation.py:94: RuntimeWarning: invalid value encountered in double_scalars
#   (-abs(current_symbol - self.constellation[const_index]) ** 2) / noise_var)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/commpy/modulation.py:94: RuntimeWarning: divide by zero encountered in double_scalars
#   (-abs(current_symbol - self.constellation[const_index]) ** 2) / noise_var)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/commpy/modulation.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   (-abs(current_symbol - self.constellation[const_index]) ** 2) / noise_var)
# 254 ms ± 7.11 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
